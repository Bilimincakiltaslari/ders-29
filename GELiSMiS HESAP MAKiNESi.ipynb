# %%
from math import *
print(37*"*")
print("Gelişmiş Hesap Makinesine Hoşgeldiniz")
print(37*"*")
def printAlan(sekil,alan):
    print( sekil + " alanı = " + str(alan))
def toplama():
    print("Toplamak istediğiniz sayılar:(boşluk bırakarak yazınız)")
    toplananlar = [int(x) for x in input().split()]
    toplam = 0
    for i in toplananlar:
        toplam += i
        print(toplam)
def cikarma():
    print("Çıkarmak istediğiniz sayılar:")
    x = int(input("Eksilen:"))
    y = int(input("Çıkan:"))
    print(x-y)
def carpma():
    print("Çarpmak istediğiniz sayılar:(boşluk bırakarak yazınız)")
    carpanlar = [int(x) for x in input().split()]
    carpım = 1
    for i in carpanlar:
        carpım *= i
        print(carpım)  
def basbolme():
    bolunen=float(input("Bölünen:"))
    bolen=float(input("Bölen:"))
    bolum=int(bolunen/bolen)
    kalan=float(bolunen%bolen)
    print("bölüm:",bolum)
    print("kalan:",kalan)
def gelısbolme():
    bolunen=float(input("Bölünen:"))
    bolen=float(input("Bölen:"))
    bolum=float(bolunen/bolen)
    print("Bölüm:",bolum)
def karealma():
    karesialınan=float(input("Karesi Alınacak Sayı:"))
    karesi=karesialınan**2
    print(karesi)
def hipotenus():
    firstdik=float(input("Dik Kenarın 1.si:"))
    seconddik=float(input("Dik Kenarın 2.si:"))
    hipo=(firstdik*firstdik+seconddik*seconddik)**0.5
    print(hipo)
def kupcevre():
    karekenar=float(input("Küpün Herhangi Bir Kenarını Giriniz:")) #50. satır
    karekenarcevre=4*(karekenar**2)
    print(karekenarcevre)
def kupalan():
    karekenara=float(input("Küpün Herhangi Bir Kenarını Giriniz:"))
    karekenaralan=6*(karekenara**2)
    printAlan("Küp", karekenaralan)
def dairecevre():
    pi=float(input("Varsayılan Pi:"))
    dairer=float(input("Yarıçapı Giriniz:"))
    dairecevresonuc=2*pi*dairer
    print(dairecevresonuc)
def dairealan():
    pi=float(input("Varsayılan Pi:"))
    dairer=float(input("Yarıçapı Giriniz:"))
    dairealansonuc=(pi)*(dairer**2)
    printAlan("Daire",dairealansonuc)
def kureyuzeyalan():
    pi=float(input("Varsayılan Pi:"))
    dairer=float(input("Yarıçapı Giriniz:"))
    kureyuzeyalansonuc=4*(pi)*(dairer**2)
    printAlan("Kürenin Alanı",kureyuzeyalansonuc)
def kurehacim():
    pi=float(input("Varsayılan Pi:"))
    dairer=float(input("Yarıçapı Giriniz:"))
    kurehacimsonuc=(4/3)*(pi)*(dairer**3)
    print(kurehacimsonuc)
while True:
    print("İşlemler:")
    print("Matematik için        m + enter")
    print("Geometri için         g + enter")
    print("Fizik için            f + enter")
    print("Programdan Çıkış için ç + enter")
    islem=input("Ders harfini giriniz ")
    if islem=="ç":
        print("Bizi Tercih Ettiğiniz İçin Sağolun.Yine bekleriz...")
        break
    if (islem == "m"):
        print("işlemler:\n1. Toplama\n2. Çıkarma\n3. Çarpma\n4. Basit Bölme(Kalanlı)\n5. Gelişmiş Bölme(Kalansız)\n6. Faktöriyel\n7. Yukarı Yuvarlama\n8. Aşağı Yuvarlama\n9. Üs Alma\n10. Karekök Alma\n11. Karesi Alma\nq. Programdan Çıkış")          
        kkk =input("İşlem no giriniz:") # 110. Satır
        if (kkk == "1"):
            toplama()
        elif (kkk == "2"):
            cikarma()  
        elif (kkk=="3"):
            carpma()
        elif (kkk=="4"):
            basbolme()
        elif (kkk=="5"):
            gelısbolme()
        elif (kkk == "6"):
            facyap=int(input("Faktöriyel'i alınacak sayıyı giriniz:"))
            facsonuc=factorial(facyap)
            print(facsonuc)
        elif (kkk == "7"):
            ustyuvar=float(input("Yukarı Yuvarlanacak Sayı:"))
            print(ceil(ustyuvar))
        elif (kkk == "8"):
            altyuvar=float(input("Aşağı Yuvarlanacak Sayı:"))
            print(floor(altyuvar))   # 130.Satır
        elif (kkk == "9"):
            usalınan=int(input("Üssü Alınacak Sayı:"))
            us=int(input("Üs:"))
            print(int(pow(usalınan,us)))
        elif (kkk == "10"):
            kokalınan=int(input("Karekök'ü Alınacak Sayı:"))
            print(sqrt(kokalınan))
        elif(kkk== "11"):
            karealma()
        elif (kkk == "q"):
            print("Bizi Tercih Ettiğiniz İçin Sağolun.Yine bekleriz....")
            break
        else:
            print("Girdiğiniz Değer Doğru Değil")
    if (islem =="g"):
        print("işlemler:")
        print("1. Hipotenüs")
        print("2. Dairenin Çevresi")
        print("3. Dairenin Alanı")
        print("4. Küpün yanal alanı")
        print("5. Küpün Alanı")
        print("6. Kürenin Alanı")
        print("7. Kürenin Hacmi")
        print("q. Programdan Çıkış") 
        lll =str(input("İşlemi giriniz:"))   
        if(lll=="1"):
            hipotenus()
        elif(lll=="2"):
            dairecevre()
        elif(lll=="3"):
            dairealan
        elif(lll=="4"):
            kupcevre()
        elif(lll=="5"):
            kupalan()
        elif(lll=="6"):
            kureyuzeyalan()
        elif(lll=="7"):
            kurehacim()
        else:
            print("yanlış tuş basımı")
# Out:
# *************************************
# Gelişmiş Hesap Makinesine Hoşgeldiniz
# *************************************
# İşlemler:
# Matematik için        m + enter
# Geometri için         g + enter
# Fizik için            f + enter
# Programdan Çıkış için ç + enter
# Ders harfini giriniz g
# işlemler:
# 1. Hipotenüs
# 2. Dairenin Çevresi
# 3. Dairenin Alanı
# 4. Küpün yanal alanı
# 5. Küpün Alanı
# 6. Kürenin Alanı
# 7. Kürenin Hacmi
# q. Programdan Çıkış
# İşlemi giriniz:5
# Küpün Herhangi Bir Kenarını Giriniz:2
# Küp alanı = 24.0
# İşlemler:
# Matematik için        m + enter
# Geometri için         g + enter
# Fizik için            f + enter
# Programdan Çıkış için ç + enter
# Ders harfini giriniz g
# işlemler:
# 1. Hipotenüs
# 2. Dairenin Çevresi
# 3. Dairenin Alanı
# 4. Küpün yanal alanı
# 5. Küpün Alanı
# 6. Kürenin Alanı
# 7. Kürenin Hacmi
# q. Programdan Çıkış
# İşlemi giriniz:6
# Varsayılan Pi:3
# Yarıçapı Giriniz:1
# Kürenin Alanı alanı = 12.0
# İşlemler:
# ...
